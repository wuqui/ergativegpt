# %%
from pathlib import Path
from dotenv import load_dotenv
from IPython.display import Markdown

import pandas as pd
import altair as alt

from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.pydantic_v1 import BaseModel, Field
from typing import Literal
from langchain.chains.openai_functions import create_structured_output_runnable

from tqdm.notebook import tqdm

from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# %% [markdown]
# # read data

# %%
fps = list(Path('../in/2024-06-27/data').glob('*'))
fps
# Out:
# [PosixPath('../in/2024-06-27/data/Data_GPT.xlsx'),
#  PosixPath('../in/2024-06-27/data/Data_GPT_V2.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Upload.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Install.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Film.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Air.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Stream.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Download.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Screen.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Update.xlsx')]

# %%
fp = Path('../in/2024-06-27/data/NOW_Update.xlsx')

# %%
df = pd.read_excel(fp)

# %%
column_spec = { 
	'causativity': ['causative', 'anticausative'],
	'transitivity': ['transitive', 'intransitive'],
	'semantic_transitivity': ['transitive', 'intransitive'],
	'subject_animacy': ['animate', 'inanimate'],
	'subject_role': ['agent', 'patient'],
}

# %%
def read_data(fp):

    df = pd.read_excel(fp) 

    column_spec = { 
        'causativity': ['causative', 'anticausative'],
        'transitivity': ['transitive', 'intransitive'],
        'semantic_transitivity': ['transitive', 'intransitive'],
        'subject_animacy': ['animate', 'inanimate'],
        'subject_role': ['agent', 'patient'],
    }

    # fix wrong values
    df['transitivity']= df['transitivity'].str.replace('transitive ', 'transitive')
    df['subject_animacy']= df['subject_animacy'].str.replace('animate ', 'animate')
    df['subject_role']= (df['subject_role'].str
                         .replace('agent ', 'agent')
                         .replace('patient ', 'patient'))
    df['causativity']= df['causativity'].str.replace('causative ', 'causative')
    df['semantic_transitivity']= df['semantic_transitivity'].str.replace('transitive ', 'transitive')

    for col in column_spec.keys():
        # check if all relevant columns are present
        assert col in df.columns, f'{fp}: column `{col}` not found in columns'
        assert 'text' in df.columns, f'{fp}: column `text` not found in columns'
        assert 'verb_realization' in df.columns, f'{fp}: column `verb_real` not found in columns'
        # check if only target values are present
        for val in df[col].unique():
            assert val in column_spec[col], f'{fp} -- colummn `{col}` -- value `{val}` not found'
    
    return df

# %%
for fp in fps:
    read_data(fp)

# %%
read_data(fp)
# Out:
#                                                  text  \
# 0                Updated on Mar 24, 2022 10:57 AM IST
# 1   Originally, the National Archives said 12,879 ...
# 2   The NCAA announced earlier this week that it h...
# 3   But he says, when you update software, you can...
# 4   A community meeting will be held in December t...
# ..                                                ...
# 95  TSA PreCheck, a program that allows trusted tr...
# 96  My thesis adviser suggested I think about upda...
# 97  We'd double-check with the company before maki...
# 98  We have updated the story to make clear why Zh...
# 99  That system will be updated so that it can be ...
#
#                                                source  year verb_realization  \
# 0   https://hindustantimes.com/photos/lifestyle/ma...  2022          updated
# 1   https://abcnews.go.com/Politics/trove-jfk-assa...  2022          updated
# 2   https://www.nationalreview.com/news/upenn-may-...  2022          updated
# 3   https://www.fool.com/investing/2022/01/26/ebay...  2022           update
# 4   https://sports.yahoo.com/several-years-camden-...  2022           update
# ..                                                ...   ...              ...
# 95  https://www.nydailynews.com/news/national/ny-t...  2022          updated
# 96  https://www.washingtonpost.com/lifestyle/2022/...  2022         updating
# 97  https://www.fool.com/the-ascent/insurance/auto...  2022          updated
# 98  https://www.propublica.org/article/editors-not...  2022          updated
# 99  https://news.yahoo.com/asheville-leaders-ditch...  2022          updated
#
#    verb_lemma  transitivity  gpt_transitivity semantic_transitivity  \
# 0      update  intransitive               NaN            transitive
# 1      update    transitive               NaN            transitive
# 2      update    transitive               NaN            transitive
# 3      update    transitive               NaN            transitive
# 4      update    transitive               NaN            transitive
# ..        ...           ...               ...                   ...
# 95     update  intransitive               NaN            transitive
# 96     update    transitive               NaN            transitive
# 97     update  intransitive               NaN            transitive
# 98     update    transitive               NaN            transitive
# 99     update  intransitive               NaN            transitive
#
#    causativity  gpt_causativity subject_animacy  gpt_subject_animacy  \
# 0    causative              NaN       inanimate                  NaN
# 1    causative              NaN         animate                  NaN
# 2    causative              NaN         animate                  NaN
# 3    causative              NaN         animate                  NaN
# 4    causative              NaN         animate                  NaN
# ..         ...              ...             ...                  ...
# 95   causative              NaN       inanimate                  NaN
# 96   causative              NaN         animate                  NaN
# 97   causative              NaN       inanimate                  NaN
# 98   causative              NaN         animate                  NaN
# 99   causative              NaN       inanimate                  NaN
#
#    subject_role  gpt_subject_role
# 0       patient               NaN
# 1         agent               NaN
# 2         agent               NaN
# 3         agent               NaN
# 4         agent               NaN
# ..          ...               ...
# 95      patient               NaN
# 96        agent               NaN
# 97      patient               NaN
# 98        agent               NaN
# 99      patient               NaN
#
# [100 rows x 14 columns]

# %% [markdown]
# # set up model

# %%
load_dotenv()
# Out:
# True

# %%
model="gpt-4o"
# model="gpt-4-turbo"

llm = ChatOpenAI(model=model, temperature=0)

# %%
with open('../in/2024-06-27/prompt.md', 'r') as f:
        prompt_txt = f.read()

# %%
# Markdown(prompt_txt)

# %%
prompt = ChatPromptTemplate.from_messages([
        ('system', prompt_txt),
        ('human', 'Please classify the following sentence: {input}')
])

# %%
class UtteranceClassification(BaseModel):
    """Classifying verbs according to several linguistic criteria."""
    gpt_transitivity: Literal['transitive', 'intransitive'] = Field(..., description="Whether this use of the verb should be labelled either `transitive` or `intransitive`.")
    gpt_causativity: Literal['causative', 'anticausative'] = Field(..., description="Whether this use of the verb should be labelled as `causative` or `anticausative`.")
    gpt_subject_role: Literal['agent', 'patient'] = Field(..., description='Whether the semantic role of the subject of the verb should be labelled as either `agent` or `patient`.')
    gpt_subject_animacy: Literal['animate', 'inanimate'] = Field(..., description='Whether the subject of the verb should be labelled as `animate` or `inanimate`.')
    gpt_subject: str = Field(..., description='The subject in this utterance that you considered for your classification.')
    gpt_verb: str = Field(..., description='The verb in this utterance that you considered for your classification.')
    gpt_object: str = Field(..., description='The object in this utterance that you considered for your classification.')

# %%
var_descs = []
for field_name, field in UtteranceClassification.__fields__.items():
	var_descs.append({"field_name": field_name, "description": field.field_info.description})

var_descs_df = pd.DataFrame(var_descs)

# %%
runnable = create_structured_output_runnable(UtteranceClassification, llm, prompt)

# %% [markdown]
# # run classification

# %%
fps
# Out:
# [PosixPath('../in/2024-06-27/data/Data_GPT.xlsx'),
#  PosixPath('../in/2024-06-27/data/Data_GPT_V2.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Upload.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Install.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Film.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Air.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Stream.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Download.xlsx'),
#  PosixPath('../in/2024-06-27/data/COHA_Screen.xlsx'),
#  PosixPath('../in/2024-06-27/data/NOW_Update.xlsx')]

# %%
verb = 'upload'

# %%
df = read_data('../in/2024-06-27/data/NOW_Upload.xlsx')

# %%
results_list = []

df_dev = (df
    #   .sample(10)
      )

for _, row in tqdm(df_dev.iterrows(), total=len(df_dev)):
    try:
        result = runnable.invoke({"input": row['verb_realization'] + ' in: ' + row['text']})
        row_data = {
            'text': row['text'],
            'transitivity': row['transitivity'],
            'gpt_transitivity': result.gpt_transitivity,
            'causativity': row['causativity'],
            'gpt_causativity': result.gpt_causativity,
            'subject_animacy': row['subject_animacy'],
            'gpt_subject_animacy': result.gpt_subject_animacy,
            'subject_role': row['subject_role'],
            'gpt_subject_role': result.gpt_subject_role,
            'gpt_subject': result.gpt_subject,
            'gpt_verb': result.gpt_verb,
            'gpt_object': result.gpt_object
        }
        results_list.append(row_data)
    except:
        continue

results = pd.DataFrame(results_list)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
results
# Out:
#                                                 text  transitivity  \
# 0  EA couldn't celebrate its win for long, though...    transitive
# 1  The shots in use currently are mostly from a s...    transitive
# 2  Created by former bankers Mickey Down and Konr...    transitive
# 3  We update when possible, but deals expire and ...  intransitive
# 4  However, if no rating change occurs, the data ...  intransitive
# 5  Now updated for Insider Preview Build 22000.46...  intransitive
# 6  Also, at the same time, they can track and upd...    transitive
# 7  While it was partially updated with new inform...  intransitive
# 8  (ADP data courtesy of MyFantasyLeague.com; las...  intransitive
# 9               Updated on Apr 03, 2022 04:13 AM IST  intransitive
#
#   gpt_transitivity causativity gpt_causativity subject_animacy  \
# 0       transitive   causative       causative         animate
# 1       transitive   causative       causative         animate
# 2       transitive   causative       causative       inanimate
# 3     intransitive   causative       causative         animate
# 4     intransitive   causative   anticausative       inanimate
# 5     intransitive   causative   anticausative       inanimate
# 6       transitive   causative       causative         animate
# 7       transitive   causative       causative       inanimate
# 8     intransitive   causative   anticausative       inanimate
# 9     intransitive   causative   anticausative       inanimate
#
#   gpt_subject_animacy subject_role gpt_subject_role            gpt_subject  \
# 0             animate        agent            agent        the Netherlands
# 1             animate        agent            agent                      I
# 2             animate        agent            agent             the series
# 3             animate        agent            agent                     We
# 4           inanimate      patient          patient  the data on this page
# 5           inanimate      patient          patient                    Now
# 6             animate        agent            agent                   they
# 7           inanimate      patient          patient                     it
# 8           inanimate      patient          patient               ADP data
# 9           inanimate      patient          patient     (implicit subject)
#
#   gpt_verb                                         gpt_object
# 0   update                   its legal definition of gambling
# 1  updated                                               them
# 2  updates                                               them
# 3   update
# 4   update
# 5  updated
# 6   update                        their actions and behaviors
# 7  updated  with new information about Russia's war on Ukr...
# 8  updated
# 9  updated
